# %% [markdown]
# # Paquetes a utilizar

# %%
import pandas as pd
import numpy as np
import sklearn as skl
from sklearn import preprocessing, model_selection, metrics
import xgboost as xgb
from boruta import BorutaPy

# Fix de alias deprecados en NumPy (requerido por Boruta < 0.4.4)
np.int   = np.int32
np.float = np.float64
np.bool  = np.bool_

# %% [markdown]
# # Carga de la base

# %%
df = pd.read_csv("data/db.csv")

# Renombrar la variable objetivo
df = df.rename(columns={"pobreza": "Label"})
print(df["Label"].value_counts())
# Out:
# Label
# No pobre          5639
# Pobre no extr.    3989
# Pobre ext.        1908
# Name: count, dtype: int64

# %% [markdown]
# ## Exploración rápida

# %%
df.describe().T
# Out:
#            count         mean          std  min      25%     50%      75%  \
# NUMHOG   11536.0  5768.500000  3330.300687  1.0  2884.75  5768.5  8652.25
# P01F03   11536.0   205.346047  1671.703363  0.0     0.00     0.0     0.00
# P15B02   11536.0    10.852462   104.289978  0.0     0.00     0.0     0.00
# P15B04   11536.0    75.097868   790.772822  0.0     0.00     0.0     0.00
# P15B06A  11536.0     0.061026     0.283185  0.0     0.00     0.0     0.00
# P13A02A  11536.0     0.400659     0.669359  0.0     0.00     0.0     1.00
# P09F03B  11536.0     1.030687     1.781403  0.0     0.00     0.0     1.00
# P09F03C  11536.0    15.830531    26.062729  0.0     0.00     0.0    30.00
# P09F04B  11536.0     7.043083     7.907098  0.0     2.00     5.0    10.00
# P09F04C  11536.0    16.137916    30.785303  0.0     0.00     0.0    30.00
# P09F05B  11536.0     2.936807     5.873105  0.0     0.00     0.0     4.00
# P09F05C  11536.0     3.126474    13.049386  0.0     0.00     0.0     0.00
# P09F06B  11536.0     0.147365     1.027894  0.0     0.00     0.0     0.00
# P09F06C  11536.0     0.341540     3.622933  0.0     0.00     0.0     0.00
# P09F07B  11536.0     0.484397     2.081587  0.0     0.00     0.0     0.00
# P09F07C  11536.0     0.909587     7.396333  0.0     0.00     0.0     0.00
# P09F08B  11536.0     0.361997     1.156212  0.0     0.00     0.0     0.00
# P09F08C  11536.0     5.159067    16.293310  0.0     0.00     0.0     0.00
# P09F09B  11536.0     5.517337     6.191571  0.0     0.00     4.0     8.00
# P09F09C  11536.0    13.901786    28.465743  0.0     0.00     0.0    30.00
# P10B20B  11536.0    27.448509   145.782264  0.0     0.00     0.0     0.00
# P11A05B  11536.0   223.088159   874.271343  0.0     0.00     0.0     0.00
# P11A06B  11536.0   365.332351  1614.840479  0.0     0.00     0.0     0.00
# P06B10A  11536.0     0.073134     0.290388  0.0     0.00     0.0     0.00
# P06B10B  11536.0     9.024329    10.674380  0.0     0.00     5.0    15.00
# P09A03B  11536.0     0.870566     2.283863  0.0     0.00     0.0     0.00
# P09A03C  11536.0     0.162369     2.049633  0.0     0.00     0.0     0.00
# P09B02B  11536.0     0.091508     0.519467  0.0     0.00     0.0     0.00
# P09B02C  11536.0     4.270836     9.329816  0.0     0.00     0.0     0.00
# P06B01   11536.0     3.218187     1.945638  0.0     2.00     3.0     4.00
# P10B01   11536.0     1.122604     0.440035  0.0     1.00     1.0     1.25
# P10B08   11536.0  1352.479726  1678.245905  0.0     0.00  1020.0  2000.00
#
#              max
# NUMHOG   11536.0
# P01F03   64800.0
# P15B02    4000.0
# P15B04   36700.0
# P15B06A      8.0
# P13A02A      5.0
# P09F03B     30.0
# P09F03C    340.0
# P09F04B     77.0
# P09F04C    370.0
# P09F05B     97.0
# P09F05C    210.0
# P09F06B     41.0
# P09F06C     90.0
# P09F07B     51.0
# P09F07C    240.0
# P09F08B     18.0
# P09F08C    210.0
# P09F09B     56.0
# P09F09C    360.0
# P10B20B   3500.0
# P11A05B  22200.0
# P11A06B  45000.0
# P06B10A      4.0
# P06B10B     60.0
# P09A03B     15.0
# P09A03C     50.0
# P09B02B     15.0
# P09B02C     50.0
# P06B01      20.0
# P10B01       3.0
# P10B08   45000.0

# %%
df.dtypes
# Out:
# NUMHOG     float64
# Label       object
# P01F03     float64
# P15B02     float64
# P15B04     float64
# P15B06A    float64
# P13A02A    float64
# P09F03B    float64
# P09F03C    float64
# P09F04B    float64
# P09F04C    float64
# P09F05B    float64
# P09F05C    float64
# P09F06B    float64
# P09F06C    float64
# P09F07B    float64
# P09F07C    float64
# P09F08B    float64
# P09F08C    float64
# P09F09B    float64
# P09F09C    float64
# P10B20B    float64
# P11A05B    float64
# P11A06B    float64
# P06B10A    float64
# P06B10B    float64
# P09A03B    float64
# P09A03C    float64
# P09B02B    float64
# P09B02C    float64
# P06B01       int64
# P10B01     float64
# P10B08     float64
# dtype: object

# %% [markdown]
# # Preparar variable dependiente y codificar etiquetas

# %%
y_raw = df["Label"].values
label_enc = preprocessing.LabelEncoder()
Y = label_enc.fit_transform(y_raw)
print(np.unique(Y, return_counts=True))
# Out:
# (array([0, 1, 2]), array([5639, 1908, 3989]))

# %% [markdown]
# # Escalado de X

# %%
X = df.drop(columns=["Label"])
feature_names = X.columns.to_numpy()

scaler = preprocessing.StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Train / test split

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X_scaled, Y, test_size=0.25, random_state=42, stratify=Y
)

# %% [markdown]
# # Modelo XGBoost para Boruta

# %%
xgb_base = xgb.XGBClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="multi:softprob",
    eval_metric="mlogloss",
    random_state=42,
)

boruta_sel = BorutaPy(
    estimator=xgb_base,
    n_estimators="auto",
    verbose=2,
    random_state=42,
)

boruta_sel.fit(X_train, y_train)
X_train_sel = boruta_sel.transform(X_train)
X_test_sel  = boruta_sel.transform(X_test)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	8
# Iteration: 	9 / 100
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	8
# Iteration: 	10 / 100
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	8
# Iteration: 	11 / 100
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	8
# Iteration: 	12 / 100
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	8
# Iteration: 	13 / 100
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	8
# Iteration: 	14 / 100
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	8
# Iteration: 	15 / 100
# Confirmed: 	13
# Tentative: 	11
# Rejected: 	8
# Iteration: 	16 / 100
# Confirmed: 	14
# Tentative: 	8
# Rejected: 	10
# Iteration: 	17 / 100
# Confirmed: 	14
# Tentative: 	8
# Rejected: 	10
# Iteration: 	18 / 100
# Confirmed: 	14
# Tentative: 	8
# Rejected: 	10
# Iteration: 	19 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	10
# Iteration: 	20 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	10
# Iteration: 	21 / 100
# Confirmed: 	15
# Tentative: 	7
# Rejected: 	10
# Iteration: 	22 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	23 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	24 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	25 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	26 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	27 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	28 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	29 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	30 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	31 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	32 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	33 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	34 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	35 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	36 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	37 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	38 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	39 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	40 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	41 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	42 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	43 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	44 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	45 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	46 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	47 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	48 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	49 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	50 / 100
# Confirmed: 	16
# Tentative: 	6
# Rejected: 	10
# Iteration: 	51 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	52 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	53 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	54 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	55 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	56 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	57 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	58 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	59 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	60 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	61 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	62 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	63 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	64 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	65 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	66 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	67 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	68 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	69 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	70 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	71 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	72 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	73 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	74 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	75 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	76 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	77 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	78 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	79 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	80 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	81 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	82 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	83 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	84 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	85 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	86 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	87 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	88 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	89 / 100
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	10
# Iteration: 	90 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	91 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	92 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	93 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	94 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	95 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	96 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	97 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	98 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	99 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	12

# %% [markdown]
# # Ranking de características

# %%
feature_ranks = list(
    zip(feature_names, boruta_sel.ranking_, boruta_sel.support_)
)

for feat, rank, keep in feature_ranks:
    print(f"Feature: {feat:<30}  Rank: {rank:<2}  Keep: {keep}")
# Out:
# Feature: NUMHOG                          Rank: 1   Keep: True
# Feature: P01F03                          Rank: 3   Keep: False
# Feature: P15B02                          Rank: 9   Keep: False
# Feature: P15B04                          Rank: 1   Keep: True
# Feature: P15B06A                         Rank: 5   Keep: False
# Feature: P13A02A                         Rank: 1   Keep: True
# Feature: P09F03B                         Rank: 1   Keep: True
# Feature: P09F03C                         Rank: 2   Keep: False
# Feature: P09F04B                         Rank: 1   Keep: True
# Feature: P09F04C                         Rank: 1   Keep: True
# Feature: P09F05B                         Rank: 1   Keep: True
# Feature: P09F05C                         Rank: 12  Keep: False
# Feature: P09F06B                         Rank: 13  Keep: False
# Feature: P09F06C                         Rank: 11  Keep: False
# Feature: P09F07B                         Rank: 9   Keep: False
# Feature: P09F07C                         Rank: 10  Keep: False
# Feature: P09F08B                         Rank: 4   Keep: False
# Feature: P09F08C                         Rank: 1   Keep: True
# Feature: P09F09B                         Rank: 1   Keep: True
# Feature: P09F09C                         Rank: 1   Keep: True
# Feature: P10B20B                         Rank: 2   Keep: False
# Feature: P11A05B                         Rank: 1   Keep: True
# Feature: P11A06B                         Rank: 1   Keep: True
# Feature: P06B10A                         Rank: 1   Keep: True
# Feature: P06B10B                         Rank: 1   Keep: True
# Feature: P09A03B                         Rank: 1   Keep: True
# Feature: P09A03C                         Rank: 3   Keep: False
# Feature: P09B02B                         Rank: 7   Keep: False
# Feature: P09B02C                         Rank: 6   Keep: False
# Feature: P06B01                          Rank: 1   Keep: True
# Feature: P10B01                          Rank: 1   Keep: True
# Feature: P10B08                          Rank: 1   Keep: True

# %% [markdown]
# # Entrenamiento final y predicciones

# %%
xgb_final = xgb.XGBClassifier(
    n_estimators=400,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.9,
    colsample_bytree=0.9,
    objective="multi:softprob",
    eval_metric="mlogloss",
    random_state=42,
)

xgb_final.fit(X_train_sel, y_train)
y_pred     = xgb_final.predict(X_test_sel)
y_proba    = xgb_final.predict_proba(X_test_sel)

# %% [markdown]
# # Métricas de desempeño

# %%
acc = metrics.accuracy_score(y_test, y_pred)
f1_macro = metrics.f1_score(y_test, y_pred, average="macro")
auc_macro = metrics.roc_auc_score(
    y_test, y_proba, multi_class="ovr", average="macro"
)

print(f"Accuracy   : {acc:.4f}")
print(f"F1 macro   : {f1_macro:.4f}")
print(f"AUC‑ROC macro : {auc_macro:.4f}\\n")
print(metrics.classification_report(y_test, y_pred))
# Out:
# Accuracy   : 0.6078
# F1 macro   : 0.5492
# AUC‑ROC macro : 0.7716\n
#               precision    recall  f1-score   support
#
#            0       0.70      0.78      0.74      1410
#            1       0.56      0.34      0.42       477
#            2       0.48      0.49      0.49       997
#
#     accuracy                           0.61      2884
#    macro avg       0.58      0.54      0.55      2884
# weighted avg       0.60      0.61      0.60      2884
