# %% [markdown]
# # Paquetes a utilizar

# %%
import sklearn as skl
import pandas as pd
import numpy as np
import xgboost as xgb
from boruta import BorutaPy

# %% [markdown]
# # Base de datos

# %%
df = pd.read_csv("data/db.csv")
#df = df.dropna()
df = df.rename(columns={'pobreza':'Label'})
df['Label'].value_counts()
# Out:
# Label
# No pobre          5639
# Pobre no extr.    3989
# Pobre ext.        1908
# Name: count, dtype: int64

# %%
df.describe().T
# Out:
#               count         mean          std  min          25%          50%  \
# Unnamed: 0  11536.0  5767.500000  3330.300687  0.0  2883.750000  5767.500000
# P01F03      11536.0   205.346047  1671.703363  0.0     0.000000     0.000000
# P15B02      11536.0    10.852462   104.289978  0.0     0.000000     0.000000
# P15B04      11536.0    75.097868   790.772822  0.0     0.000000     0.000000
# P15B06A     11536.0     0.061026     0.283185  0.0     0.000000     0.000000
# P13A02A     11536.0     0.400659     0.669359  0.0     0.000000     0.000000
# P06B01      11536.0     3.218187     1.945638  0.0     2.000000     3.000000
# P06B10A     11536.0     0.028528     0.122511  0.0     0.000000     0.000000
# P06B10B     11536.0     3.328799     4.496532  0.0     0.000000     1.500000
# P09A03B     11536.0     0.271926     0.816723  0.0     0.000000     0.000000
# P09A03C     11536.0     0.052020     0.675160  0.0     0.000000     0.000000
# P09B02B     11536.0     0.030853     0.200823  0.0     0.000000     0.000000
# P09B02C     11536.0     1.494675     3.618752  0.0     0.000000     0.000000
# P09F03B     11536.0     0.223393     0.397640  0.0     0.000000     0.000000
# P09F03C     11536.0     3.581792     5.926458  0.0     0.000000     0.000000
# P09F04B     11536.0     1.539624     1.561686  0.0     0.400000     1.111111
# P09F04C     11536.0     3.516644     6.528189  0.0     0.000000     0.000000
# P09F05B     11536.0     0.572266     1.072054  0.0     0.000000     0.000000
# P09F05C     11536.0     0.624090     2.699909  0.0     0.000000     0.000000
# P09F06B     11536.0     0.038626     0.311347  0.0     0.000000     0.000000
# P09F06C     11536.0     0.081365     1.002183  0.0     0.000000     0.000000
# P09F07B     11536.0     0.108293     0.463089  0.0     0.000000     0.000000
# P09F07C     11536.0     0.214939     1.794663  0.0     0.000000     0.000000
# P09F08B     11536.0     0.083493     0.285300  0.0     0.000000     0.000000
# P09F08C     11536.0     1.227673     4.023717  0.0     0.000000     0.000000
# P09F09B     11536.0     1.191026     1.167185  0.0     0.000000     1.000000
# P09F09C     11536.0     3.018689     6.042142  0.0     0.000000     0.000000
# P10B01      11536.0     0.504347     0.321255  0.0     0.285714     0.500000
# P10B08      11536.0   489.878935   760.128299  0.0     0.000000   300.000000
# P10B20B     11536.0     6.334541    41.592380  0.0     0.000000     0.000000
# P11A05B     11536.0    81.464898   439.981895  0.0     0.000000     0.000000
# P11A06B     11536.0   105.072263   516.232794  0.0     0.000000     0.000000
#
#                     75%           max
# Unnamed: 0  8651.250000  11535.000000
# P01F03         0.000000  64800.000000
# P15B02         0.000000   4000.000000
# P15B04         0.000000  36700.000000
# P15B06A        0.000000      8.000000
# P13A02A        1.000000      5.000000
# P06B01         4.000000     20.000000
# P06B10A        0.000000      3.000000
# P06B10B        5.000000     30.000000
# P09A03B        0.000000      8.571429
# P09A03C        0.000000     18.750000
# P09B02B        0.000000     10.000000
# P09B02C        0.000000     37.500000
# P09F03B        0.333333     10.500000
# P09F03C        6.000000     50.000000
# P09F04B        2.200000     13.000000
# P09F04C        5.000000     50.000000
# P09F05B        0.777778     12.800000
# P09F05C        0.000000     50.000000
# P09F06B        0.000000     13.000000
# P09F06C        0.000000     45.000000
# P09F07B        0.000000     12.000000
# P09F07C        0.000000     30.000000
# P09F08B        0.000000     11.000000
# P09F08C        0.000000     45.000000
# P09F09B        1.833333     11.000000
# P09F09C        4.285714     45.000000
# P10B01         0.666667      3.000000
# P10B08       650.000000  21600.000000
# P10B20B        0.000000   2000.000000
# P11A05B        0.000000  20910.000000
# P11A06B        0.000000  12920.000000

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Label          object
# P01F03        float64
# P15B02        float64
# P15B04        float64
# P15B06A       float64
# P13A02A       float64
# P06B01          int64
# P06B10A       float64
# P06B10B       float64
# P09A03B       float64
# P09A03C       float64
# P09B02B       float64
# P09B02C       float64
# P09F03B       float64
# P09F03C       float64
# P09F04B       float64
# P09F04C       float64
# P09F05B       float64
# P09F05C       float64
# P09F06B       float64
# P09F06C       float64
# P09F07B       float64
# P09F07C       float64
# P09F08B       float64
# P09F08C       float64
# P09F09B       float64
# P09F09C       float64
# P10B01        float64
# P10B08        float64
# P10B20B       float64
# P11A05B       float64
# P11A06B       float64
# dtype: object

# %% [markdown]
# # Variable dependiente que debe predecirse y codificación de datos categóricos

# %%
y = df["Label"].values
Y = skl.preprocessing.LabelEncoder().fit_transform(y)
Y
# Out:
# array([0, 0, 2, ..., 2, 0, 1], shape=(11536,))

# %% [markdown]
# # Definir x, normalizar valores y definir variables independientes

# %%
X = df.drop(labels = ["Label"], axis=1) 
nombres_de_funciones = np.array(X.columns)
scaler = skl.preprocessing.StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %% [markdown]
# # Train and test para verificar la precisión después de ajustar el modelo

# %%
X_train, X_test, y_train, y_test = skl.model_selection.train_test_split(X, Y, test_size=0.25, random_state=42)

# %% [markdown]
# # XGBOOST para ser utilizado por Boruta

# %%
modelo = xgb.XGBClassifier()

# %% [markdown]
# - Crear funciones de sombra: funciones aleatorias y valores aleatorios en columnas
# - Entrenar Random Forest / XGBoost y calcular la importancia de la característica a través de la disminución media de la impureza
# - Comprobar si las características reales tienen mayor importancia en comparación con las características de sombra
# - Repetir esto para cada iteración
# - Si la función original funcionó mejor, marcarla como importante.

# %%
np.int = np.int32
np.float = np.float64
np.bool = np.bool_

# %%
# Especificar cómo se determinan las características relevantes utilizando el algoritmo Boruta
selector = BorutaPy(modelo, n_estimators='auto', verbose=2, random_state=1)
# Hallar todas las características importantes
selector.fit(X_train, y_train)
# Aplicar el método transform() en el conjunto de datos X para limitarlo a solo las características seleccionadas
X_filtered = selector.transform(X_train)  # Utilizar técnicas de selección de características y obtener el conjunto de datos modificado
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	10
# Iteration: 	9 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	10
# Iteration: 	10 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	10
# Iteration: 	11 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	10
# Iteration: 	12 / 100
# Confirmed: 	14
# Tentative: 	6
# Rejected: 	12
# Iteration: 	13 / 100
# Confirmed: 	14
# Tentative: 	6
# Rejected: 	12
# Iteration: 	14 / 100
# Confirmed: 	14
# Tentative: 	6
# Rejected: 	12
# Iteration: 	15 / 100
# Confirmed: 	14
# Tentative: 	6
# Rejected: 	12
# Iteration: 	16 / 100
# Confirmed: 	14
# Tentative: 	5
# Rejected: 	13
# Iteration: 	17 / 100
# Confirmed: 	14
# Tentative: 	5
# Rejected: 	13
# Iteration: 	18 / 100
# Confirmed: 	14
# Tentative: 	5
# Rejected: 	13
# Iteration: 	19 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	20 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	21 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	22 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	23 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	24 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	25 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	26 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	27 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	28 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	29 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	30 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	31 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	32 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	33 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	34 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	35 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	36 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	37 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	38 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	39 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	40 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	41 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	42 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	43 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	44 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	45 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	46 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	47 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	48 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	49 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	50 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	51 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	52 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	53 / 100
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	14
# Iteration: 	54 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	55 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	56 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	57 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	58 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	59 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	60 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	61 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	62 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	63 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	64 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	65 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	66 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	67 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	68 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	69 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	70 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	71 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	72 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	73 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	74 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	75 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	76 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	77 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	78 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	79 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	80 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	81 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	82 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	83 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	84 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	85 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	86 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	87 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	88 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	89 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	90 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	91 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	92 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	93 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	94 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	95 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	96 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	97 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	98 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
# Iteration: 	99 / 100
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	14
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	15
# Tentative: 	1
# Rejected: 	16

# %% [markdown]
# # zip nombres de características, rangos y decisiones

# %%
feature_ranks = list(zip(nombres_de_funciones, 
                         selector.ranking_, 
                         selector.support_))

# %% [markdown]
# # Resultados

# %%
for feat in feature_ranks:
    print('Feature: {:<30} Rank: {},  Keep: {}'.format(feat[0], feat[1], feat[2]))
# Out:
# Feature: Unnamed: 0                     Rank: 1,  Keep: True
# Feature: P01F03                         Rank: 12,  Keep: False
# Feature: P15B02                         Rank: 9,  Keep: False
# Feature: P15B04                         Rank: 2,  Keep: False
# Feature: P15B06A                        Rank: 4,  Keep: False
# Feature: P13A02A                        Rank: 1,  Keep: True
# Feature: P06B01                         Rank: 1,  Keep: True
# Feature: P06B10A                        Rank: 1,  Keep: True
# Feature: P06B10B                        Rank: 1,  Keep: True
# Feature: P09A03B                        Rank: 3,  Keep: False
# Feature: P09A03C                        Rank: 15,  Keep: False
# Feature: P09B02B                        Rank: 6,  Keep: False
# Feature: P09B02C                        Rank: 8,  Keep: False
# Feature: P09F03B                        Rank: 1,  Keep: True
# Feature: P09F03C                        Rank: 5,  Keep: False
# Feature: P09F04B                        Rank: 11,  Keep: False
# Feature: P09F04C                        Rank: 9,  Keep: False
# Feature: P09F05B                        Rank: 6,  Keep: False
# Feature: P09F05C                        Rank: 14,  Keep: False
# Feature: P09F06B                        Rank: 13,  Keep: False
# Feature: P09F06C                        Rank: 18,  Keep: False
# Feature: P09F07B                        Rank: 15,  Keep: False
# Feature: P09F07C                        Rank: 17,  Keep: False
# Feature: P09F08B                        Rank: 1,  Keep: True
# Feature: P09F08C                        Rank: 1,  Keep: True
# Feature: P09F09B                        Rank: 1,  Keep: True
# Feature: P09F09C                        Rank: 1,  Keep: True
# Feature: P10B01                         Rank: 1,  Keep: True
# Feature: P10B08                         Rank: 1,  Keep: True
# Feature: P10B20B                        Rank: 1,  Keep: True
# Feature: P11A05B                        Rank: 1,  Keep: True
# Feature: P11A06B                        Rank: 1,  Keep: True

# %%
xgb_model = xgb.XGBClassifier()
xgb_model.fit(X_filtered, y_train)
X_test_filtered = selector.transform(X_test)
prediction_xgb = xgb_model.predict(X_test_filtered)

# %% [markdown]
# ## Precisión

# %%
skl.metrics.accuracy_score(y_test, prediction_xgb)
# Out:
# 0.6567267683772539

# %%
from sklearn.metrics import f1_score, roc_auc_score, classification_report, RocCurveDisplay

y_pred = prediction_xgb
f1_macro = f1_score(y_test, y_pred, average='macro')
print(f"F1 macro: {f1_macro:.4f}")

y_proba = xgb_model.predict_proba(X_test_filtered)
auc_macro = roc_auc_score(
    y_test,
    y_proba,
    multi_class='ovr',
    average='macro'
)
print(f"Macro AUC‑ROC (OvR): {auc_macro:.4f}")


print(classification_report(y_test, y_pred))
# Out:
# F1 macro: 0.6142
# Macro AUC‑ROC (OvR): 0.8175
#               precision    recall  f1-score   support
#
#            0       0.75      0.81      0.78      1388
#            1       0.60      0.46      0.52       485
#            2       0.54      0.54      0.54      1011
#
#     accuracy                           0.66      2884
#    macro avg       0.63      0.60      0.61      2884
# weighted avg       0.65      0.66      0.65      2884
